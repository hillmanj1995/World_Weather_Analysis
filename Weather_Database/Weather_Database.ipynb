# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import os

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=95120e21e0c7f91871049d8bbe213ab4

# %%
 # Create an endpoint URL for each city
city_url = url + "&q=" + city.replace(" ","+")
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 128.8694, 'lat': 71.6872},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': -10.55,
#   'feels_like': -23.15,
#   'temp_min': -10.55,
#   'temp_max': -10.55,
#   'pressure': 1012,
#   'humidity': 91,
#   'sea_level': 1012,
#   'grnd_level': 1006},
#  'visibility': 10000,
#  'wind': {'speed': 12.15, 'deg': 234, 'gust': 24.16},
#  'clouds': {'all': 100},
#  'dt': 1668489841,
#  'sys': {'country': 'RU', 'sunrise': 1668477609, 'sunset': 1668485887},
#  'timezone': 32400,
#  'id': 2015306,
#  'name': 'Tiksi',
#  'cod': 200}

# %%
description = city_weather['weather'][0]['description']
description
# Out:
# 'overcast clouds'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | tukrah
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | kommunisticheskiy
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | goedereede
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | roura
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | sambava
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | katsuyama
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | vila velha
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | san patricio
# Processing Record 22 of Set 1 | belluru
# Processing Record 23 of Set 1 | ravar
# Processing Record 24 of Set 1 | clyde river
# Processing Record 25 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | ternate
# Processing Record 29 of Set 1 | lukow
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | narsaq
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | marquette
# Processing Record 35 of Set 1 | nioro
# Processing Record 36 of Set 1 | coahuayana
# Processing Record 37 of Set 1 | maceio
# Processing Record 38 of Set 1 | ouricuri
# Processing Record 39 of Set 1 | bambous virieux
# Processing Record 40 of Set 1 | hofn
# Processing Record 41 of Set 1 | bunia
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 1 | puerto leguizamo
# Processing Record 46 of Set 1 | sao paulo de olivenca
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | hof
# Processing Record 49 of Set 1 | laguna
# Processing Record 50 of Set 1 | nemuro
# Processing Record 1 of Set 2 | chernyshevskiy
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | kokopo
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | saint george
# Processing Record 9 of Set 2 | sinnamary
# Processing Record 10 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 2 | sao filipe
# Processing Record 12 of Set 2 | haines junction
# Processing Record 13 of Set 2 | cidreira
# Processing Record 14 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 15 of Set 2 | necochea
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | mesyagutovo
# Processing Record 20 of Set 2 | teluknaga
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | tuatapere
# Processing Record 25 of Set 2 | steamboat springs
# Processing Record 26 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 2 | valdivia
# Processing Record 28 of Set 2 | ojinaga
# Processing Record 29 of Set 2 | taltal
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | dingle
# Processing Record 32 of Set 2 | erenhot
# Processing Record 33 of Set 2 | rondonopolis
# Processing Record 34 of Set 2 | codrington
# Processing Record 35 of Set 2 | plonsk
# Processing Record 36 of Set 2 | busselton
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | shakhtinsk
# Processing Record 39 of Set 2 | ahmadpur east
# Processing Record 40 of Set 2 | mayo
# Processing Record 41 of Set 2 | daru
# Processing Record 42 of Set 2 | san alberto
# Processing Record 43 of Set 2 | lebu
# Processing Record 44 of Set 2 | chulman
# Processing Record 45 of Set 2 | severo-kurilsk
# Processing Record 46 of Set 2 | iracoubo
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | mataura
# Processing Record 50 of Set 2 | nhulunbuy
# Processing Record 1 of Set 3 | luau
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | aykhal
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | ignatovka
# Processing Record 6 of Set 3 | marystown
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | yerbogachen
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | maningrida
# Processing Record 12 of Set 3 | beyneu
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | iqaluit
# Processing Record 15 of Set 3 | villa carlos paz
# Processing Record 16 of Set 3 | husavik
# Processing Record 17 of Set 3 | hobart
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | tiznit
# Processing Record 20 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 3 | mahebourg
# Processing Record 22 of Set 3 | krasnoselkup
# Processing Record 23 of Set 3 | shenjiamen
# Processing Record 24 of Set 3 | carnarvon
# Processing Record 25 of Set 3 | svetlogorsk
# Processing Record 26 of Set 3 | kovdor
# Processing Record 27 of Set 3 | opuwo
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | provost
# Processing Record 31 of Set 3 | khash
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | touros
# Processing Record 34 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 3 | leningradskiy
# Processing Record 36 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 3 | bredasdorp
# Processing Record 38 of Set 3 | boa vista
# Processing Record 39 of Set 3 | methven
# Processing Record 40 of Set 3 | anuchino
# Processing Record 41 of Set 3 | port elizabeth
# Processing Record 42 of Set 3 | norsup
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | adrar
# Processing Record 45 of Set 3 | new norfolk
# Processing Record 46 of Set 3 | nelson bay
# Processing Record 47 of Set 3 | namatanai
# Processing Record 48 of Set 3 | victoria
# Processing Record 49 of Set 3 | katsuura
# Processing Record 50 of Set 3 | san policarpo
# Processing Record 1 of Set 4 | ahipara
# Processing Record 2 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 4 | san carlos de bariloche
# Processing Record 4 of Set 4 | chokurdakh
# Processing Record 5 of Set 4 | meadow lake
# Processing Record 6 of Set 4 | dikson
# Processing Record 7 of Set 4 | kjopsvik
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | santa marta
# Processing Record 10 of Set 4 | natal
# Processing Record 11 of Set 4 | oksovskiy
# Processing Record 12 of Set 4 | bagdarin
# Processing Record 13 of Set 4 | shakiso
# Processing Record 14 of Set 4 | atuona
# Processing Record 15 of Set 4 | xinqing
# Processing Record 16 of Set 4 | haldia
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | saint-leu
# Processing Record 19 of Set 4 | dajal
# Processing Record 20 of Set 4 | khandbari
# Processing Record 21 of Set 4 | manaus
# Processing Record 22 of Set 4 | chapleau
# Processing Record 23 of Set 4 | soubre
# Processing Record 24 of Set 4 | hamilton
# Processing Record 25 of Set 4 | naze
# Processing Record 26 of Set 4 | vanimo
# Processing Record 27 of Set 4 | lamar
# Processing Record 28 of Set 4 | ancud
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | esperance
# Processing Record 31 of Set 4 | kavieng
# Processing Record 32 of Set 4 | lokachi
# Processing Record 33 of Set 4 | paramonga
# Processing Record 34 of Set 4 | wooster
# Processing Record 35 of Set 4 | mandalgovi
# Processing Record 36 of Set 4 | margate
# Processing Record 37 of Set 4 | geraldton
# Processing Record 38 of Set 4 | bereda
# Processing Record 39 of Set 4 | pelym
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | faanui
# Processing Record 42 of Set 4 | the valley
# Processing Record 43 of Set 4 | pimentel
# Processing Record 44 of Set 4 | chernyakhovsk
# Processing Record 45 of Set 4 | tautira
# Processing Record 46 of Set 4 | kemise
# Processing Record 47 of Set 4 | teacapan
# Processing Record 48 of Set 4 | buala
# Processing Record 49 of Set 4 | vaitape
# Processing Record 50 of Set 4 | henties bay
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | fukue
# Processing Record 3 of Set 5 | mirabela
# Processing Record 4 of Set 5 | portland
# Processing Record 5 of Set 5 | provideniya
# Processing Record 6 of Set 5 | salalah
# Processing Record 7 of Set 5 | fortuna
# Processing Record 8 of Set 5 | vestmannaeyjar
# Processing Record 9 of Set 5 | ulladulla
# Processing Record 10 of Set 5 | abrau-dyurso
# Processing Record 11 of Set 5 | vanderhoof
# Processing Record 12 of Set 5 | jamestown
# Processing Record 13 of Set 5 | luderitz
# Processing Record 14 of Set 5 | miramar
# Processing Record 15 of Set 5 | narwar
# Processing Record 16 of Set 5 | grindavik
# Processing Record 17 of Set 5 | marrakesh
# Processing Record 18 of Set 5 | bom conselho
# Processing Record 19 of Set 5 | jasper
# Processing Record 20 of Set 5 | pacific grove
# Processing Record 21 of Set 5 | nizhniy tsasuchey
# Processing Record 22 of Set 5 | wenling
# Processing Record 23 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 24 of Set 5 | lavrentiya
# Processing Record 25 of Set 5 | kloulklubed
# Processing Record 26 of Set 5 | sorong
# Processing Record 27 of Set 5 | oktyabrskoye
# Processing Record 28 of Set 5 | katherine
# Processing Record 29 of Set 5 | kuybysheve
# Processing Record 30 of Set 5 | safford
# Processing Record 31 of Set 5 | saldanha
# Processing Record 32 of Set 5 | enumclaw
# Processing Record 33 of Set 5 | cairns
# Processing Record 34 of Set 5 | korampallam
# Processing Record 35 of Set 5 | ginda
# Processing Record 36 of Set 5 | sayyan
# Processing Record 37 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 5 | dekoa
# City not found. Skipping...
# Processing Record 39 of Set 5 | ningyang
# Processing Record 40 of Set 5 | ribeira grande
# Processing Record 41 of Set 5 | erdenet
# Processing Record 42 of Set 5 | saskylakh
# Processing Record 43 of Set 5 | luanda
# Processing Record 44 of Set 5 | lahij
# Processing Record 45 of Set 5 | tuktoyaktuk
# Processing Record 46 of Set 5 | izhma
# Processing Record 47 of Set 5 | pueblo
# Processing Record 48 of Set 5 | port lincoln
# Processing Record 49 of Set 5 | brae
# Processing Record 50 of Set 5 | ixtapa
# Processing Record 1 of Set 6 | alexandria
# Processing Record 2 of Set 6 | umm kaddadah
# Processing Record 3 of Set 6 | airai
# Processing Record 4 of Set 6 | burgeo
# Processing Record 5 of Set 6 | lovozero
# Processing Record 6 of Set 6 | tazovskiy
# Processing Record 7 of Set 6 | huanren
# Processing Record 8 of Set 6 | berikulskiy
# City not found. Skipping...
# Processing Record 9 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 6 | ambikapur
# Processing Record 11 of Set 6 | zhigansk
# Processing Record 12 of Set 6 | piacabucu
# Processing Record 13 of Set 6 | anadyr
# Processing Record 14 of Set 6 | taperoa
# Processing Record 15 of Set 6 | avarua
# Processing Record 16 of Set 6 | sola
# Processing Record 17 of Set 6 | biak
# Processing Record 18 of Set 6 | escanaba
# Processing Record 19 of Set 6 | quelimane
# Processing Record 20 of Set 6 | rockhampton
# Processing Record 21 of Set 6 | santa maria
# Processing Record 22 of Set 6 | bengkulu
# Processing Record 23 of Set 6 | pisco
# Processing Record 24 of Set 6 | viedma
# Processing Record 25 of Set 6 | juegang
# Processing Record 26 of Set 6 | lodwar
# Processing Record 27 of Set 6 | dawson creek
# Processing Record 28 of Set 6 | vila franca do campo
# Processing Record 29 of Set 6 | tateyama
# Processing Record 30 of Set 6 | adre
# Processing Record 31 of Set 6 | najran
# Processing Record 32 of Set 6 | turukhansk
# Processing Record 33 of Set 6 | rakhya
# City not found. Skipping...
# Processing Record 34 of Set 6 | ishigaki
# Processing Record 35 of Set 6 | aklavik
# Processing Record 36 of Set 6 | puerto del rosario
# Processing Record 37 of Set 6 | matara
# Processing Record 38 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 6 | santa cruz de la palma
# Processing Record 40 of Set 6 | buraydah
# Processing Record 41 of Set 6 | cuiluan
# Processing Record 42 of Set 6 | ust-ishim
# Processing Record 43 of Set 6 | lakes entrance
# Processing Record 44 of Set 6 | meulaboh
# Processing Record 45 of Set 6 | voyvozh
# Processing Record 46 of Set 6 | yumen
# Processing Record 47 of Set 6 | rovaniemi
# Processing Record 48 of Set 6 | namibe
# Processing Record 49 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 6 | los llanos de aridane
# Processing Record 1 of Set 7 | ahuimanu
# Processing Record 2 of Set 7 | bethel
# Processing Record 3 of Set 7 | pompeu
# Processing Record 4 of Set 7 | kharabali
# Processing Record 5 of Set 7 | baykit
# Processing Record 6 of Set 7 | barabinsk
# Processing Record 7 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 7 | povenets
# Processing Record 9 of Set 7 | belawan
# Processing Record 10 of Set 7 | faya
# Processing Record 11 of Set 7 | labuhan
# Processing Record 12 of Set 7 | tuy hoa
# Processing Record 13 of Set 7 | soyo
# Processing Record 14 of Set 7 | broome
# Processing Record 15 of Set 7 | tiksi
# Processing Record 16 of Set 7 | itoman
# Processing Record 17 of Set 7 | eureka
# Processing Record 18 of Set 7 | bandarbeyla
# Processing Record 19 of Set 7 | waw
# Processing Record 20 of Set 7 | khon kaen
# Processing Record 21 of Set 7 | morondava
# Processing Record 22 of Set 7 | surt
# Processing Record 23 of Set 7 | sao gabriel da cachoeira
# Processing Record 24 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 25 of Set 7 | seoul
# Processing Record 26 of Set 7 | bolshoye ignatovo
# City not found. Skipping...
# Processing Record 27 of Set 7 | auki
# Processing Record 28 of Set 7 | dryden
# Processing Record 29 of Set 7 | anchorage
# Processing Record 30 of Set 7 | rawlins
# Processing Record 31 of Set 7 | tortoli
# Processing Record 32 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 33 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 7 | kandrian
# Processing Record 35 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 7 | cervo
# Processing Record 37 of Set 7 | paamiut
# Processing Record 38 of Set 7 | sitka
# Processing Record 39 of Set 7 | vikhorevka
# Processing Record 40 of Set 7 | muravlenko
# Processing Record 41 of Set 7 | tanout
# Processing Record 42 of Set 7 | asfi
# Processing Record 43 of Set 7 | manali
# Processing Record 44 of Set 7 | souillac
# Processing Record 45 of Set 7 | port hardy
# Processing Record 46 of Set 7 | nagyszenas
# Processing Record 47 of Set 7 | bandipur
# Processing Record 48 of Set 7 | panjwin
# City not found. Skipping...
# Processing Record 49 of Set 7 | teahupoo
# Processing Record 50 of Set 7 | hokitika
# Processing Record 1 of Set 8 | raudeberg
# Processing Record 2 of Set 8 | cabo san lucas
# Processing Record 3 of Set 8 | bosaso
# Processing Record 4 of Set 8 | tessalit
# Processing Record 5 of Set 8 | mahuva
# Processing Record 6 of Set 8 | bonavista
# Processing Record 7 of Set 8 | black diamond
# Processing Record 8 of Set 8 | wahiawa
# Processing Record 9 of Set 8 | kalabo
# Processing Record 10 of Set 8 | suntar
# Processing Record 11 of Set 8 | rawson
# Processing Record 12 of Set 8 | masvingo
# Processing Record 13 of Set 8 | shingu
# Processing Record 14 of Set 8 | cayenne
# Processing Record 15 of Set 8 | havoysund
# Processing Record 16 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 8 | harper
# Processing Record 18 of Set 8 | cartagena
# Processing Record 19 of Set 8 | padang
# Processing Record 20 of Set 8 | porto novo
# Processing Record 21 of Set 8 | kozhva
# Processing Record 22 of Set 8 | stephenville
# Processing Record 23 of Set 8 | kaitangata
# Processing Record 24 of Set 8 | gurupa
# Processing Record 25 of Set 8 | kinna
# Processing Record 26 of Set 8 | banjar
# Processing Record 27 of Set 8 | hobyo
# Processing Record 28 of Set 8 | moron
# Processing Record 29 of Set 8 | deputatskiy
# Processing Record 30 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 8 | kuldur
# Processing Record 32 of Set 8 | asamankese
# Processing Record 33 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 34 of Set 8 | wloszczowa
# Processing Record 35 of Set 8 | paithan
# Processing Record 36 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 37 of Set 8 | chinsali
# Processing Record 38 of Set 8 | alekseyevka
# Processing Record 39 of Set 8 | matay
# Processing Record 40 of Set 8 | artesia
# Processing Record 41 of Set 8 | amahai
# Processing Record 42 of Set 8 | bam
# Processing Record 43 of Set 8 | mount isa
# Processing Record 44 of Set 8 | nizwa
# Processing Record 45 of Set 8 | marietta
# Processing Record 46 of Set 8 | santiago del estero
# Processing Record 47 of Set 8 | narrabri
# Processing Record 48 of Set 8 | khandyga
# Processing Record 49 of Set 8 | kikuchi
# Processing Record 50 of Set 8 | ostrovnoy
# Processing Record 1 of Set 9 | newport
# Processing Record 2 of Set 9 | lerwick
# Processing Record 3 of Set 9 | yayva
# Processing Record 4 of Set 9 | sao joao da barra
# Processing Record 5 of Set 9 | nsanje
# Processing Record 6 of Set 9 | saint-georges
# Processing Record 7 of Set 9 | isla mujeres
# Processing Record 8 of Set 9 | zunyi
# Processing Record 9 of Set 9 | port-cartier
# Processing Record 10 of Set 9 | ostrov
# Processing Record 11 of Set 9 | avenal
# Processing Record 12 of Set 9 | sucua
# Processing Record 13 of Set 9 | khani
# Processing Record 14 of Set 9 | praia
# Processing Record 15 of Set 9 | balabac
# Processing Record 16 of Set 9 | riohacha
# Processing Record 17 of Set 9 | tahoua
# Processing Record 18 of Set 9 | asau
# Processing Record 19 of Set 9 | si bun ruang
# Processing Record 20 of Set 9 | ardon
# Processing Record 21 of Set 9 | vao
# Processing Record 22 of Set 9 | kahului
# Processing Record 23 of Set 9 | dingzhou
# Processing Record 24 of Set 9 | waipawa
# Processing Record 25 of Set 9 | lata
# Processing Record 26 of Set 9 | hassleholm
# Processing Record 27 of Set 9 | karasburg
# Processing Record 28 of Set 9 | drumheller
# Processing Record 29 of Set 9 | lorengau
# Processing Record 30 of Set 9 | tarakan
# Processing Record 31 of Set 9 | dali
# Processing Record 32 of Set 9 | sai buri
# Processing Record 33 of Set 9 | grand gaube
# Processing Record 34 of Set 9 | la ronge
# Processing Record 35 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 36 of Set 9 | caravelas
# Processing Record 37 of Set 9 | ouesso
# Processing Record 38 of Set 9 | meiktila
# Processing Record 39 of Set 9 | vestmanna
# Processing Record 40 of Set 9 | komsomolskiy
# Processing Record 41 of Set 9 | palana
# Processing Record 42 of Set 9 | taksimo
# Processing Record 43 of Set 9 | balingasay
# Processing Record 44 of Set 9 | tromso
# Processing Record 45 of Set 9 | kushiro
# Processing Record 46 of Set 9 | brigantine
# Processing Record 47 of Set 9 | devarkonda
# Processing Record 48 of Set 9 | hudson bay
# Processing Record 49 of Set 9 | kismayo
# Processing Record 50 of Set 9 | lensk
# Processing Record 1 of Set 10 | hounde
# Processing Record 2 of Set 10 | northam
# Processing Record 3 of Set 10 | severo-yeniseyskiy
# Processing Record 4 of Set 10 | shimoda
# Processing Record 5 of Set 10 | amuntai
# Processing Record 6 of Set 10 | boksitogorsk
# Processing Record 7 of Set 10 | sokoto
# Processing Record 8 of Set 10 | plouzane
# Processing Record 9 of Set 10 | kemijarvi
# Processing Record 10 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 10 | ponta delgada
# Processing Record 12 of Set 10 | taoudenni
# Processing Record 13 of Set 10 | noumea
# Processing Record 14 of Set 10 | kruisfontein
# Processing Record 15 of Set 10 | vostok
# Processing Record 16 of Set 10 | aripuana
# Processing Record 17 of Set 10 | coralville
# Processing Record 18 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 19 of Set 10 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 20 of Set 10 | poum
# Processing Record 21 of Set 10 | khor
# Processing Record 22 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 10 | vyartsilya
# Processing Record 24 of Set 10 | pontalina
# Processing Record 25 of Set 10 | acapulco
# Processing Record 26 of Set 10 | coquimbo
# Processing Record 27 of Set 10 | te anau
# Processing Record 28 of Set 10 | inirida
# Processing Record 29 of Set 10 | ayorou
# Processing Record 30 of Set 10 | gizo
# Processing Record 31 of Set 10 | cumbal
# Processing Record 32 of Set 10 | storforshei
# Processing Record 33 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 10 | rocha
# Processing Record 35 of Set 10 | beringovskiy
# Processing Record 36 of Set 10 | nogliki
# Processing Record 37 of Set 10 | leh
# Processing Record 38 of Set 10 | comarapa
# Processing Record 39 of Set 10 | mount darwin
# Processing Record 40 of Set 10 | sabha
# Processing Record 41 of Set 10 | aporawan
# City not found. Skipping...
# Processing Record 42 of Set 10 | kautokeino
# Processing Record 43 of Set 10 | hualmay
# Processing Record 44 of Set 10 | cabedelo
# Processing Record 45 of Set 10 | listvyanka
# Processing Record 46 of Set 10 | hami
# Processing Record 47 of Set 10 | tura
# Processing Record 48 of Set 10 | jumla
# Processing Record 49 of Set 10 | sampang
# Processing Record 50 of Set 10 | berkakit
# Processing Record 1 of Set 11 | iquique
# Processing Record 2 of Set 11 | huaraz
# Processing Record 3 of Set 11 | brokopondo
# Processing Record 4 of Set 11 | dauphin
# Processing Record 5 of Set 11 | lutz
# Processing Record 6 of Set 11 | lufilufi
# Processing Record 7 of Set 11 | morro bay
# Processing Record 8 of Set 11 | bratca
# Processing Record 9 of Set 11 | aldan
# Processing Record 10 of Set 11 | smithers
# Processing Record 11 of Set 11 | balkanabat
# Processing Record 12 of Set 11 | shache
# Processing Record 13 of Set 11 | alofi
# Processing Record 14 of Set 11 | shush
# Processing Record 15 of Set 11 | springbok
# Processing Record 16 of Set 11 | xingyi
# Processing Record 17 of Set 11 | wamba
# Processing Record 18 of Set 11 | san juan de los morros
# Processing Record 19 of Set 11 | aguililla
# Processing Record 20 of Set 11 | baie-comeau
# Processing Record 21 of Set 11 | pimampiro
# Processing Record 22 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 23 of Set 11 | lumsden
# Processing Record 24 of Set 11 | meridian
# Processing Record 25 of Set 11 | cibitoke
# Processing Record 26 of Set 11 | trairi
# Processing Record 27 of Set 11 | gravdal
# Processing Record 28 of Set 11 | togur
# Processing Record 29 of Set 11 | damaturu
# Processing Record 30 of Set 11 | kuandian
# Processing Record 31 of Set 11 | kralendijk
# Processing Record 32 of Set 11 | nargana
# Processing Record 33 of Set 11 | vysokogornyy
# Processing Record 34 of Set 11 | atar
# Processing Record 35 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 11 | naples
# Processing Record 37 of Set 11 | lewistown
# Processing Record 38 of Set 11 | kilindoni
# Processing Record 39 of Set 11 | virginia beach
# Processing Record 40 of Set 11 | ko samui
# Processing Record 41 of Set 11 | westport
# Processing Record 42 of Set 11 | gejiu
# Processing Record 43 of Set 11 | birao
# Processing Record 44 of Set 11 | ballina
# Processing Record 45 of Set 11 | leo
# Processing Record 46 of Set 11 | yulara
# Processing Record 47 of Set 11 | kattivakkam
# Processing Record 48 of Set 11 | camacha
# Processing Record 49 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 50 of Set 11 | isperih
# Processing Record 1 of Set 12 | minot
# Processing Record 2 of Set 12 | ankazoabo
# Processing Record 3 of Set 12 | minnedosa
# Processing Record 4 of Set 12 | paveh
# Processing Record 5 of Set 12 | sawakin
# Processing Record 6 of Set 12 | kyzyl-mazhalyk
# Processing Record 7 of Set 12 | mangan
# Processing Record 8 of Set 12 | titron
# Processing Record 9 of Set 12 | nikolayevsk-na-amure
# Processing Record 10 of Set 12 | valparaiso
# Processing Record 11 of Set 12 | chumikan
# Processing Record 12 of Set 12 | barra patuca
# Processing Record 13 of Set 12 | pochutla
# Processing Record 14 of Set 12 | buckeye
# Processing Record 15 of Set 12 | beloha
# Processing Record 16 of Set 12 | norden
# Processing Record 17 of Set 12 | mudgee
# Processing Record 18 of Set 12 | mabaruma
# Processing Record 19 of Set 12 | sorland
# Processing Record 20 of Set 12 | lamu
# Processing Record 21 of Set 12 | guerrero negro
# Processing Record 22 of Set 12 | medicine hat
# Processing Record 23 of Set 12 | nenjiang
# Processing Record 24 of Set 12 | ivangorod
# Processing Record 25 of Set 12 | mount gambier
# Processing Record 26 of Set 12 | santona
# Processing Record 27 of Set 12 | dunedin
# Processing Record 28 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 29 of Set 12 | nouakchott
# Processing Record 30 of Set 12 | leshukonskoye
# Processing Record 31 of Set 12 | mersing
# Processing Record 32 of Set 12 | sitrah
# Processing Record 33 of Set 12 | emba
# Processing Record 34 of Set 12 | luwuk
# Processing Record 35 of Set 12 | ondangwa
# Processing Record 36 of Set 12 | maniitsoq
# Processing Record 37 of Set 12 | chor
# Processing Record 38 of Set 12 | borogontsy
# Processing Record 39 of Set 12 | monrovia
# Processing Record 40 of Set 12 | wajima
# Processing Record 41 of Set 12 | tadine
# Processing Record 42 of Set 12 | sobolevo
# Processing Record 43 of Set 12 | cotonou
# Processing Record 44 of Set 12 | chunhuhub
# Processing Record 45 of Set 12 | fairbanks
# Processing Record 46 of Set 12 | tommot
# Processing Record 47 of Set 12 | ekhabi
# Processing Record 48 of Set 12 | shugurovo
# Processing Record 49 of Set 12 | oussouye
# Processing Record 50 of Set 12 | lazaro cardenas
# Processing Record 1 of Set 13 | luang prabang
# Processing Record 2 of Set 13 | rio claro
# Processing Record 3 of Set 13 | obernai
# Processing Record 4 of Set 13 | lasa
# Processing Record 5 of Set 13 | ayamonte
# Processing Record 6 of Set 13 | bardiyah
# Processing Record 7 of Set 13 | micheweni
# Processing Record 8 of Set 13 | abalak
# Processing Record 9 of Set 13 | macia
# Processing Record 10 of Set 13 | manicore
# Processing Record 11 of Set 13 | takoradi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
city_data_count = len(city_data)
city_data_count
# Out:
# 563

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Kodiak  57.7900 -152.4072     31.51        93           0
# 1             Barrow  71.2906 -156.7887     -2.18        84          20
# 2             Tukrah  32.5341   20.5791     63.05        78           6
# 3        Yellowknife  62.4560 -114.3525     25.32       100         100
# 4  Kommunisticheskiy  61.6789   64.4819      1.24        89         100
# 5       Puerto Ayora  -0.7393  -90.3518     69.55        85          54
# 6         Goedereede  51.8175    3.9806     52.05        91         100
# 7              Vaini -21.2000 -175.2000     77.16        94          40
# 8              Roura   4.7263  -52.3274     76.91        94          20
# 9             Hasaki  35.7333  140.8333     56.21        80         100
#
#    Wind Speed Country Current Description
# 0        5.75      US           clear sky
# 1       13.80      US                mist
# 2        5.84      LY          light rain
# 3       12.66      CA          light snow
# 4       11.36      RU     overcast clouds
# 5        1.99      EC       broken clouds
# 6        4.00      NL     overcast clouds
# 7        9.22      TO             drizzle
# 8        2.30      GF          few clouds
# 9       12.73      JP     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]


# Recreate the DataFrame by using the new column order
organized_city_data_df = city_data_df[new_column_order]


# Display sample data
organized_city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Kodiak      US  57.7900 -152.4072     31.51        93
# 1             Barrow      US  71.2906 -156.7887     -2.18        84
# 2             Tukrah      LY  32.5341   20.5791     63.05        78
# 3        Yellowknife      CA  62.4560 -114.3525     25.32       100
# 4  Kommunisticheskiy      RU  61.6789   64.4819      1.24        89
# 5       Puerto Ayora      EC  -0.7393  -90.3518     69.55        85
# 6         Goedereede      NL  51.8175    3.9806     52.05        91
# 7              Vaini      TO -21.2000 -175.2000     77.16        94
# 8              Roura      GF   4.7263  -52.3274     76.91        94
# 9             Hasaki      JP  35.7333  140.8333     56.21        80
#
#    Cloudiness  Wind Speed Current Description
# 0           0        5.75           clear sky
# 1          20       13.80                mist
# 2           6        5.84          light rain
# 3         100       12.66          light snow
# 4         100       11.36     overcast clouds
# 5          54        1.99       broken clouds
# 6         100        4.00     overcast clouds
# 7          40        9.22             drizzle
# 8          20        2.30          few clouds
# 9         100       12.73     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
organized_city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name

from pathlib import Path

output_file = 'WeatherPy_Database.csv'
output_dir = Path('Weather_Database')

output_dir.mkdir(parents=True, exist_ok=True)

organized_city_data_df.to_csv(output_dir / output_file)  # can join path elements with / operator

# Export the city_data DataFrame into a CSV file
#organized_city_data_df.to_csv("Week 6 (2022.11.07-13)_Challenge\Weather_Database", index_label="City_ID")

# %%
print("my path is ", os.getcwd())
# Out:
# my path is  C:\Users\jhillman\Desktop\Data Analytics Bootcamp\Week 6 (2022.11.07-13)_Challenge\Weather_Database
